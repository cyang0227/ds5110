# %% [markdown]
# # Yahoo Finance Fundamentals Data Exploration

# %%
import yfinance as yf
import pandas as pd
pd.set_option("display.max_rows", 100)

# %%
tickers = ["ASML", "NVDA", "AAPL"]
t = yf.Ticker(tickers[0])
print(f"Exploring {tickers[0]}")
# Out:
# Exploring ASML

# %%
info = t.info
print("\n=== INFO KEYS ===")
print(list(info.keys()))  # see what exists
pd.DataFrame([info]).T.head(30)
# Out:
# === INFO KEYS ===
# ...

# %%
# Financial Statements Info
print("\n=== Income Statement (Quarterly) ===")
display(t.quarterly_income_stmt.head(20))
# Out:
# === Income Statement (Quarterly) ===
#                                                       2025-09-30  \
# Tax Effect Of Unusual Items                         0.000000e+00
# Tax Rate For Calcs                                  1.777470e-01
# Normalized EBITDA                                   2.743000e+09
# Net Income From Continuing Operation Net Minori...  2.124500e+09
# Reconciled Depreciation                             2.746000e+08
# Reconciled Cost Of Revenue                          3.635700e+09
# EBITDA                                              2.743000e+09
# EBIT                                                2.468400e+09
# Net Interest Income                                 1.940000e+07
# Interest Income                                              NaN
# Normalized Income                                   2.124500e+09
# Net Income From Continuing And Discontinued Ope...  2.124500e+09
# Total Expenses                                      5.047600e+09
# ...

# %% [markdown]
# # Unfortunately, I can only get the recent year's financial statements, will find another source.
