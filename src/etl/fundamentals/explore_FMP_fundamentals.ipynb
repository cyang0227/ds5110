# %% [markdown]
# # Explore FMP data source (financialmodelingprep.com)

# %%
import requests
import pandas as pd
from datetime import datetime

API_KEY = "kETMJlCxls8W8I8b6OLtnt0qgph8Ek24"
BASE_URL = "https://financialmodelingprep.com/stable"

# %%
def fmp(endpoint, symbol, period="quarter"):
    """ Fetch from FMP/Stable endpoint."""
    url = f"{BASE_URL}/{endpoint}"
    resp = requests.get(url, params={
        "symbol": symbol,
        "period": period,
        "apikey": API_KEY
    })
    resp.raise_for_status()
    return resp.json()

symbol = "AAPL"
print(f"Exploring {symbol} financial data from Financial Modeling Prep...")
# Out:
# Exploring AAPL financial data from Financial Modeling Prep...
